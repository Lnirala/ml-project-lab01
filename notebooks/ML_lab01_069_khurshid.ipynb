# %% [markdown]
# <a href="https://colab.research.google.com/github/Lnirala/ml-project-lab01/blob/main/notebooks/ML_lab01_069_khurshid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, future ML detective!")
print("Rule 1: The computer is literal, not rude.")
# Out:
# Hello, future ML detective!
# Rule 1: The computer is literal, not rude.

# %%
# ==============================================================================
# LAB 1: Welcome to Machine Learning
# Student name: Khurshid Jahan
# Student ID: 01123456789
# ==============================================================================

import numpy as np

# Base Code
np.random.seed(42)
marks = np.array([55, 72, 48, 90, 66, 81])

print('Marks:', marks)
print('Mean:', marks.mean())
print('Highest:', marks.max())
print('Passed:', marks[marks >= 50])

# ------------------------------------------------------------------------------
# Student Tasks Solutions:
# ------------------------------------------------------------------------------

# Task 12: Find the minimum mark and standard deviation
print('Minimum:', marks.min())
print('Standard Deviation:', marks.std())

# Task 13: Add 5 bonus marks to every student without changing the original array
bonus_marks = marks + 5
print('Bonus Marks:', bonus_marks)
print('Original Marks (Unchanged):', marks)

# Task 14: Count how many students passed
passed_count = (marks >= 50).sum()
print('Passed Count:', passed_count)

# Task 15: Create a 2 x 3 matrix from the marks
matrix_2x3 = marks.reshape(2, 3)
print('2x3 Matrix:\n', matrix_2x3)
# Out:
# Marks: [55 72 48 90 66 81]
# Mean: 68.66666666666667
# Highest: 90
# Passed: [55 72 90 66 81]
# Minimum: 48
# Standard Deviation: 14.372040758206733
# Bonus Marks: [60 77 53 95 71 86]
# Original Marks (Unchanged): [55 72 48 90 66 81]
# Passed Count: 5
# 2x3 Matrix:
#  [[55 72 48]
#  [90 66 81]]

# %%
import pandas as pd

data = {
    'student': ['Asha', 'Babu', 'Chayan', 'Dipa', 'Emon', 'Farah'],
    'study_hours': [2, 5, 1, 7, 3, 6],
    'sleep_hours': [8, 6, 9, 5, 7, 6],
    'attendance': [70, 88, 55, 95, 75, 91],
    'snacks': [3, 2, 5, 1, 4, 2],
    'passed': ['Yes', 'Yes', 'No', 'Yes', 'No', 'Yes']
}

df = pd.DataFrame(data)

# Q16: Features & Label
# Features: 'study_hours', 'sleep_hours', 'attendance', 'snacks' | Label: 'passed'

# Q17: Samples & Columns
print(f"17. Rows: {df.shape[0]}, Columns: {df.shape[1]}")

# Q18: Attendance >= 80
print("\n18. Attendance >= 80:\n", df[df['attendance'] >= 80])

# Q19: Average study hours for passed students
print("\n19. Avg study hours (Passed):", df[df['passed'] == 'Yes']['study_hours'].mean())

# Q20: Sorted by attendance (descending)
print("\n20. Sorted by Attendance:\n", df.sort_values(by='attendance', ascending=False))

# Q21: Explanation
# No, correlation does not imply causation, and 6 samples are too small to draw conclusions.
# Out:
# 17. Rows: 6, Columns: 6
#
# 18. Attendance >= 80:
#    student  study_hours  sleep_hours  attendance  snacks passed
# 1    Babu            5            6          88       2    Yes
# 3    Dipa            7            5          95       1    Yes
# 5   Farah            6            6          91       2    Yes
#
# 19. Avg study hours (Passed): 5.0
#
# 20. Sorted by Attendance:
#    student  study_hours  sleep_hours  attendance  snacks passed
# 3    Dipa            7            5          95       1    Yes
# 5   Farah            6            6          91       2    Yes
# 1    Babu            5            6          88       2    Yes
# 4    Emon            3            7          75       4     No
# 0    Asha            2            8          70       3    Yes
# 2  Chayan            1            9          55       5     No

# %%
import random
import numpy as np

def generate_scores(use_seed):
    if use_seed:
        random.seed(100)
        np.random.seed(100)
    return np.random.randint(50, 96, size=6)

print('Seeded run 1:', generate_scores(True))
print('Seeded run 2:', generate_scores(True))
print('Unseeded run 1:', generate_scores(False))
print('Unseeded run 2:', generate_scores(False))
# Out:
# Seeded run 1: [58 74 53 89 73 65]
# Seeded run 2: [58 74 53 89 73 65]
# Unseeded run 1: [60 80 84 52 84 64]
# Unseeded run 2: [84 74 65 86 93 66]
